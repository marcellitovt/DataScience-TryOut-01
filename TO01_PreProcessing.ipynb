# %%
import pandas as pd

# %%
dataframe = pd.read_csv('dataset/TO-01.csv')
dataframe.head(70)
# Out:
#     NO      USERNAME                         NAMA SISWA  \
# 0    1  k04010101001              ADELIA KUSUMA NINGRUM
# 1    2  k04010101002                  AKBAR ZAHUL FIKRI
# 2    3  k04010101003              ALISA PUTRI DAMAYANTI
# 3    4  k04010101004    ANGGA KRISTA KURNIAWAN HASIBUAN
# 4    5  k04010101005              ARDITYA RIZKY PRADANA
# ..  ..           ...                                ...
# 65  62  k04010101062                   Alan Vikkiansyah
# 66  63  k04010101063           ALFANDY FIRMANSYAH PUTRA
# 67  64  k04010101064              ANISA SALMA SALSABILA
# 68  65  k04010101065  ANTONIUS RAKA PUTRA HENDRAKARTIKA
# 69  66  k04010101066         ANUGERAH PUTRA HENDRIYANTO
#
#                NAMA SEKOLAH BINDO   MTK BING TEORI JUMLAH   PROV   KAB
# 0   SMK NEGERI 2 YOGYAKARTA    76    30   82   NaN    188   3254   885
# 1   SMK NEGERI 2 YOGYAKARTA    52    15   42   NaN    109  23023  4759
# 2   SMK NEGERI 2 YOGYAKARTA    70    55   64   NaN    189   3119   842
# ...

# %%
dataframe = dataframe.dropna(subset=['USERNAME'])
dataframe = dataframe.dropna(subset=['KAB'])
dataframe.head(100)
# Out:
#       NO      USERNAME                       NAMA SISWA  \
# 0      1  k04010101001            ADELIA KUSUMA NINGRUM
# 1      2  k04010101002                AKBAR ZAHUL FIKRI
# 2      3  k04010101003            ALISA PUTRI DAMAYANTI
# 3      4  k04010101004  ANGGA KRISTA KURNIAWAN HASIBUAN
# 4      5  k04010101005            ARDITYA RIZKY PRADANA
# ..   ...           ...                              ...
# 99    96  k04010101096             AGUSTINUS YOAN CAHYA
# 100   97  k04010101097              AHMAD SYAHRUL NIZAM
# 101   98  k04010101098            ANDHIKA ARIS SETYAWAN
# 102   99  k04010101099                     ANNAS EFENDI
# 103  100  k04010101100                    ARIF SETIAWAN
#
#                 NAMA SEKOLAH BINDO   MTK BING TEORI JUMLAH   PROV   KAB
# 0    SMK NEGERI 2 YOGYAKARTA    76    30   82   NaN    188   3254   885
# 1    SMK NEGERI 2 YOGYAKARTA    52    15   42   NaN    109  23023  4759
# 2    SMK NEGERI 2 YOGYAKARTA    70    55   64   NaN    189   3119   842
# ...

# %%
#export_csv = df.to_csv (r'C:\Users\Ron\Desktop\export_dataframe.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
#export = dataframe
#export.to_csv(r'TO01_clean.csv',index=False)
