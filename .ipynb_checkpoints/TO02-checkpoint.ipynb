# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('TO-02-test.xlsx')
df
# Out:
#      No.  Nomor Peserta                      Nama Peserta Bhs Ind   Mtk  \
# 0      1  1-20401315001                        ABDUL AZIZ      76    80
# 1      2  1-20401315002               AFIF RUNDY MUTTAQIN      72    30
# 2      3  1-20401315003       AHMAD MAULANA RIZKY MUSTOFA      62    30
# 3      4  1-20401315004  ALFAREL NOOR MIARARIZKI SUTARMAN      70  62.5
# 4      5  1-20401315005                 ALFINKA ICHSANDYA      72    60
# ..   ...            ...                               ...     ...   ...
# 729  591  1-20401315591                SETO AJI RINENGKUH      62    40
# 730  592  1-20401315592        SHANA NOOR IZZA PRIYANDARA      80  77.5
# 731  593  1-20401315593                  SYAFANA MARDITYA      60  52.5
# 732  594  1-20401315594                 WAHYU DWI SAPUTRA      68  77.5
# 733  595  1-20401315595                  YUSUF DWIRINANTO      54  17.5
#
#     Bhs Ing Kej. Jumlah   Rata Kelas Sekolah   KAB
# 0        76  NaN    232  77.33     1      66    81
# ...

# %%
df = df.dropna(subset=['KAB'])
df = df.dropna(subset=['Jumlah'])
df = df.dropna(subset=['Nama Peserta'])
df.reset_index(drop=True, inplace=True)
df
# Out:
#      No.  Nomor Peserta                      Nama Peserta Bhs Ind   Mtk  \
# 0      1  1-20401315001                        ABDUL AZIZ      76    80
# 1      2  1-20401315002               AFIF RUNDY MUTTAQIN      72    30
# 2      3  1-20401315003       AHMAD MAULANA RIZKY MUSTOFA      62    30
# 3      4  1-20401315004  ALFAREL NOOR MIARARIZKI SUTARMAN      70  62.5
# 4      5  1-20401315005                 ALFINKA ICHSANDYA      72    60
# ..   ...            ...                               ...     ...   ...
# 590  591  1-20401315591                SETO AJI RINENGKUH      62    40
# 591  592  1-20401315592        SHANA NOOR IZZA PRIYANDARA      80  77.5
# 592  593  1-20401315593                  SYAFANA MARDITYA      60  52.5
# 593  594  1-20401315594                 WAHYU DWI SAPUTRA      68  77.5
# 594  595  1-20401315595                  YUSUF DWIRINANTO      54  17.5
#
#     Bhs Ing Kej. Jumlah   Rata Kelas Sekolah   KAB
# 0        76  NaN    232  77.33     1      66    81
# ...

# %%
export = df
export.to_csv(r'TO02_clean.csv',index=False)

# %%
df_clean = pd.read_csv('TO02_clean.csv')
df_clean.dtypes
# Out:
# No.                int64
# Nomor Peserta     object
# Nama Peserta      object
# Bhs Ind          float64
# Mtk              float64
# Bhs Ing            int64
# Kej.             float64
# Jumlah           float64
# Rata             float64
# Kelas              int64
# Sekolah            int64
# KAB                int64
# dtype: object
